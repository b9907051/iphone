# %% [markdown]
# # 華為

# %%
from bs4 import BeautifulSoup as Bt4
import requests
import json

# P40 尚未公布

website = f"https://www.vmall.com/product/10086885129494.html"

source = requests.get(website).text
soup = Bt4(source, "lxml")
soup
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="zh-cn" http-equiv="Content-Language"/>
# <meta content="upgrade-insecure-requests" http-equiv="Content-Security-Policy"/>
# <script>
# var domainYY   = 'https://yy.vmall.com';
# var domainRush = 'https://buy.vmall.com';
# var domainEdit = 'https://customization.vmall.com';
# var domainMain = 'https://www.vmall.com';
# var domainWap = 'https://m.vmall.com';
# var domainCart = '//cart.vmall.com';
# var domainRemark = '//remark.vmall.com';
# var domainRms = 'https://rms.vmall.com/';
# var domainShoppingConfig = '//addr.vmall.com';
# var imagePath = 'https://res.vmallres.com/20191126/images';
# var domainAccount = '//www.vmall.com';
# var isUseAccount = 'false';
# var upBindPhoneAddr = 'https://hwid1.vmall.com/oauth2/userCenter/bindAccount/bindMobileAccount_1.jsp?lang=zh-cn&amp;themeName=cloudTheme&amp;reqClientType=26';
# var dominWapRecycle ='http://mobile.huishoubao.com/?pid=1056';
# var domainCds = 'https://cds.vmall.com';
# var domainIps = 'https://cashier.vmall.com/cashier/voucher';
# var scriptPath = 'https://res9.vmallres.com/20191126/js';
# var domainAms ='https://act.vmall.com';
# var domainUc ='https://member.vmall.com';
# var openApiDomain='https://openapi.vmall.com';
# var timeOutInfo='服务器开小差了，请稍后再试！';
# var addressFrontRegex = '[A-Za-z0-9０-９ａ-ｚＡ-Ｚ一-龥.?!,。？！，、；：＇＂（）［］｛｝;:&#039;&#034;()\\[\\]{}──·····．《》〈〉＜＞.《》〈〉&lt;&gt;·—＿＿＿＿＊____*□=／\/▲●～~……→＠＃@#￥％＆＊%&amp;*\\\\——－＝＼　 -]{1,}';
# var easeBuyDomain = 'https://easy.vmall.com';
# var scriptPaths = 'https://res10.vmallres.com/20191126/js';
# var dapDomain='https://dap.vmall.com';
# var riskTimeOut = '200';
# try {
# 	if (document.cookie.indexOf('redirectWap=1') < 0 && /Android|webOS|iPhone|iPad|iPod|BlackBerry/i.test(navigator.userAgent)) {
# 		var r = null;
# 		if (['/honor', '/huawei', '/notice'].indexOf(location.pathname) > -1) {
# 			location.href = domainWap + location.pathname + location.search;
# 		} else if (['/', '/index.html'].indexOf(location.pathname) > -1) {
# 			location.href = domainWap + location.search;
# 		} else if ('/recycle' === location.pathname) {
# 			location.href = dominWapRecycle;
# 		} else if (r = (location.pathname.match(/^\/(?:product|order\/easebuy)\/(\d+)\.html$/) || [])[1]) {
# 			location.href = domainWap + '/product/' + r + '.html' + location.search;
# 		} else if (r = (location.pathname.match(/^\/list\-(\d+)/) || [])[1]) {
# 			location.href = domainWap + "/category/detail" + '-' + r + '-' + r + location.search;
# 		}
# 	}
# } catch (err) {}
# </script>
# <title>【HUAWEI Mate 20】价格_参数_图片_怎么样 - 华为商城</title>
# <meta content="HUAWEI Mate 20,HUAWEI Mate 20价格,HUAWEI Mate 20怎么样,华为商城" name="keywords"/>
# <meta content="HUAWEI Mate 20官方渠道售卖！华为商城提供最新款的HUAWEI Mate 20的价格、参数、图片等信息。官方品质保证，欢迎选购！" name="description"/>
# <link href="https://www.vmall.com/favicon.ico" rel="shortcut icon"/>
# <link href="https://res8.vmallres.com/20191126/css/echannel/ec.core.base.min.css?20200122" rel="stylesheet" type="text/css"/>
# <link href="https://res8.vmallres.com/20191126/css/echannel/main.min.css?20170609" rel="stylesheet" type="text/css"/>
# <link href="https://res8.vmallres.com/20191126/css/product/main.min.css?20170710" rel="stylesheet" type="text/css"/>
# <script namespace="ec" src="https://res10.vmallres.com/20191126/js/??/common/jsapi.js,/common/base/jquery-3.4.1.min.js,/common/base/jquery-migrate-1.4.1.min.js,/common/base/jquery-migrate-3.0.1.min.js,/common/base/helper.min.js,/common/ec.core.js,/echannel/ec.business.min.js,/echannel/base.min.js,/product2/rush.min.js,/common/jquery.qrcode.min.js,/echannel/swiper.min.js,/echannel/slider.min.js"></script>
# <script namespace="ec" src="https://res10.vmallres.com/20191126/js/??/product2/remark_details.min.js,/product2/addReply.min.js,/uum/member/commodity/remarkCommon.min.js,/product2/detail.min.js,/product2/expected_delivery.min.js,/product2/interestFree.min.js,/product2/gift.min.js,/product2/deposit_new.min.js,/product2/deposit.min.js,/product2/coupon.min.js"></script>
# <!--[if lt IE 9]><script src="https://res9.vmallres.com/20191126/js/common/html5shiv.js"></script> <![endif]-->
# </head><body><p>
# ﻿</p>
# <img class="hide" src="https://res.vmallres.com/20191126/images/echannel/icon/icon-commonnew.svg"/>
# <img class="hide" src="https://res.vmallres.com/20191126/images/echannel/icon/icon01.svg"/>
# <img class="hide" src="https://res.vmallres.com/20191126/images/echannel/bg/bg-slide.png"/>
# <style>
# .minicart-pro-item .pro-other .p-title span.p-mini-tag-suit {
#     display: block;
#     border-radius: 2px;
#     background: #ca141d;
#     color: #fff;
#     width: 42px;
#     height: 17px;
#     line-height: 17px;
#     text-align: center;
#     position: absolute;
#     left: 0;
#     border: none;
# }
# .minicart-pro-item .pro-other li.disabled .p-title span.p-mini-tag-suit {
#     color: #fff;
# }
# </style>
# <div class="top-banner" id="top-banner-block"></div>
# <!-- 20130605-qq-彩贝-start -->
# <div class="qq-caibei-bar hide" id="caibeiMsg">
# <div class="layout">
# <div class="qq-caibei-bar-tips" id="HeadShow"></div>
# <div class="qq-caibei-bar-userInfo" id="ShowMsg"></div>
# </div>
# </div>
# <!-- 20130605-qq-彩贝-end -->
# <div class="shortcut">
# <div class="layout">
# <div class="s-sub">
# <ul>
# <li><a href="https://www.vmall.com" onclick="pushHeaderMsg('首页','https://www.vmall.com')">首页</a></li>
# <li><a href="http://consumer.huawei.com/cn/" onclick="pushHeaderMsg('华为官网','http://consumer.huawei.com/cn/')" target="_blank">华为官网</a></li>
# <li><a href="http://www.honor.cn/" onclick="pushHeaderMsg('荣耀官网','http://www.honor.cn/')" target="_blank">荣耀官网</a></li>
# <li><a href="http://club.huawei.com" onclick="pushHeaderMsg('花粉俱乐部','http://club.huawei.com')" target="_blank">花粉俱乐部</a></li>
# <li><a href="javascript:;" onclick="pushHeaderMsgPriority('V码(优购码)','https://www.vmall.com/priority')" rel="nofollow">V码(优购码)</a></li>
# <li><a href="/company" onclick="pushHeaderMsg('企业购','/company')" target="_blank">企业购</a></li>
# <li class="s-hwep hide" id="li-enterprise-preferential"></li>
# <li><a href="javascript:;" onclick="showSelectRegion();pushHeaderMsg('Select Region','')">Select Region</a></li>
# <li>
# <div class="s-dropdown">
# <div class="h">
# <a class="icon-dropdown">更多精彩</a>
# </div>
# <div class="b">
# <div class="dropdown-more w-119">
# <dl>
# <dt><a href="http://emui.huawei.com/cn/" target="_blank">EMUI</a></dt>
# <dt><a href="http://appstore.huawei.com/" target="_blank">应用市场</a></dt>
# <dt><a href="http://cloud.huawei.com" target="_blank">华为终端云空间</a></dt>
# <dt><a href="http://developer.huawei.com/" target="_blank">开发者联盟</a></dt>
# </dl>
# </div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="s-main">
# <img class="hide" src="https://res.vmallres.com/20191126/images/echannel/bg/bg71.png"/>
# <ul>
# <li id="unlogin_status">
# <div class="header-toolbar" id="top_unlogin">
# <!-- 2017-02-15-头部-工具栏-焦点为header-toolbar-item增加ClassName:hover -->
# <div class="header-toolbar-item">
# <div class="i-login">
# <div class="h">
# <div class="">
# <!-- <script>document.write('<a id="top-index-loginUrl" href="https://hwid1.vmall.com/CAS/remoteLogin?loginChannel=26000000&reqClientType=26&lang=zh-cn&loginUrl=https%3A%2F%2Fid1.cloud.huawei.com%2FCAS%2Fportal%2FloginAuth.html&service=https%3A%2F%2Fwww.vmall.com%2Faccount%2Facaslogin%3Furl%3D'+encodeURIComponent(encodeURIComponent(window.location.href))+'" rel="nofollow" onclick="pushLoginMsg(\'登录\',\'\')">请登录</a>');</script> -->
# <script>document.write('<a id="top-index-loginUrl" href="javascript:;" rel="nofollow" onclick="pushLoginMsgInfoPerson(\'登录\',\'\')" style="margin-right: 8px" >请登录</a>');</script>
# <a href="https://hwid1.vmall.com/CAS/portal/userRegister/regbyphone.html?service=https://www.vmall.com/account/caslogin&amp;loginChannel=26000000&amp;reqClientType=26&amp;lang=zh-cn" onclick="pushLoginMsg('注册','')" rel="nofollow">  注册</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </li>
# <li class="hide" id="login_status">
# <div class="header-toolbar hide" id="top_login">
# <div class="s-dropdown">
# <div class="h h-wide" id="up_loginName-hover">
# <a class="icon-dropdown" href="https://www.vmall.com/member?t=1581318515756" onclick="pushLoginMsg('已登录','用户名')" rel="nofollow" target="_blank"><span id="up_loginName"></span></a>
#                             </div>
# <div class="b">
# <!-- 2017-06-19-个人信息-start -->
# <div class="dropdown-i-mall">
# <div class="i-mall-prompt clearfix">
# <div class="user-head fl">
# <p class="user-img">
# <a href="https://www.vmall.com/member?t=1581318515756timestamp" onclick="pushLoginMsg('已登录','头像')" rel="nofollow" target="_blank" timetype="timestamp">
# <img alt="默认头像" id="customerPic" imgpath="https://res.vmallres.com/20191126/images" src="https://res.vmallres.com/20191126/images/echannel/misc/img_not_logged_in.png"/>
# </a>
# </p>
# </div>
# <div class="user-info fl">
# <div class="user-level icon-vip-level-0" id="user-vip-level-tips-index">
# <em></em>
# <p><span id="canvas-index" style="width: 0%"></span></p>
# </div>
# <div class="user-info-detail clearfix" id="vip-info">
# <a class="icon-realname hide" id="authentication_y">已实名</a>
# <a class="icon-realname disabled hide" href="https://www.vmall.com/authmember/accesstoken" id="authentication_n" onclick="pushLoginMsg('已登录','未实名')" rel="nofollow">未实名</a>
# <a class="icon-mail" href="https://www.vmall.com/member/msg?t=1581318515756timestamp" onclick="pushLoginMsg('已登录','消息中心')" rel="nofollow" timetype="timestamp">消息(<span id="top-newMsgCount">0</span>)</a>
# </div>
# </div>
# </div>
# <div class="i-mall-uc">
# <dl class="clearfix">
# <dt><span class="fl">我的订单</span><a class="fr" href="https://www.vmall.com/member/order?t=1581318515756timestamp" onclick="pushLoginMsg('已登录','更多')" timetype="timestamp">更多</a></dt>
# </dl>
# <div class="i-mall-uc-con">
# <dl class="clearfix">
# <dd><a href="https://www.vmall.com/member/order?t=1581318515756timestamp&amp;tab=unpaid" onclick="pushLoginMsg('已登录','待支付')" timetype="timestamp">待支付</a></dd>
# <dd><a href="https://www.vmall.com/member/order?t=1581318515756timestamp&amp;tab=send" onclick="pushLoginMsg('已登录','待收货')" timetype="timestamp">待收货</a></dd>
# <dd><a href="https://www.vmall.com/member/order?t=1581318515756timestamp&amp;tab=nocomment" onclick="pushLoginMsg('已登录','待评价')" timetype="timestamp">待评价</a></dd>
# <dd><a href="https://www.vmall.com/member/exchange?t=1581318515756timestamp" onclick="pushLoginMsg('已登录','退换货')" timetype="timestamp">退换货</a></dd>
# <dd><a href="https://www.vmall.com/member/recycle/index/aihuishou?t=1581318515756timestamp" onclick="pushLoginMsg('已登录','旧机回收')" timetype="timestamp">旧机回收</a></dd>
# </dl>
# </div>
# </div>
# <div class="i-mall-huaban">
# <ul class="clearfix">
# <li>
# <a href="https://www.vmall.com/member/newpoint?t=1581318515756" id="point" onclick="pushLoginMsg('已登录','积分')" target="_blank">
# <p class="p-price"><span id="userPointBalance">--</span></p>
# <p class="p-dec">积分</p>
# </a>
# </li>
# <li>
# <a href="https://www.vmall.com/member/coupon?t=1581318515756" onclick="pushLoginMsg('已登录','优惠券')" rel="nofollow" target="_blank">
# <p class="p-price"><span id="top-couponCount">--</span></p>
# <p class="p-dec">优惠券</p>
# </a>
# </li>
# <li>
# <a href="https://www.vmall.com/member/balance?t=1581318515757" onclick="pushLoginMsg('已登录','代金券')" rel="nofollow" target="_blank">
# <p class="p-price"><span id="balanceAmount">--</span></p>
# <p class="p-dec">代金券</p>
# </a>
# </li>
# </ul>
# </div>
# <div class="i-out">
# <a href="https://www.vmall.com/account/logout" rel="nofollow">退出登录</a>
# </div>
# </div>
# <!-- 2017-06-19-个人信息-end -->
# </div>
# </div>
# </div>
# </li>
# <!-- <li><a href="https://www.vmall.com/member/order?t=1581318515757timestamp" timeType="timestamp" onclick = "pushMyOrderMsg()">我的订单</a></li>-->
# <li><a href="javascript:;" onclick="pushMyOrderMsg()" timetype="timestamp">我的订单</a></li>
# <li>
# <div class="s-dropdown s-dropdown-link">
# <div class="h">
# <a class="icon-dropdown">客户服务</a>
# </div>
# <div class="b">
# <div class="dropdown-more">
# <dl>
# <dt><a href="https://www.vmall.com/help/index.html" target="_blank">服务中心</a></dt>
# <dt><a href="https://celia.consumer.huawei.com/vmall/#/?businessUUID=902d812b8bdb44e089e34544fb5d77e2&amp;from=06" target="_blank">联系客服</a></dt>
# </dl>
# </div>
# </div>
# </div>
# </li>
# <li>
# <div class="s-dropdown">
# <div class="h">
# <a class="icon-dropdown" href="#" target="_blank">网站导航</a>
# </div>
# <div class="b">
# <div class="dropdown-navs clearfix">
# <p><a href="https://www.vmall.com"><div class="dropdown-navs-icon"><span style="font-size:0;"> </span>商城首页</div></a> </p><div class="fl" style="width:185.0px;margin-top:22.0px;margin-bottom:20.0px;"><div class="bold f16 black" style="margin-bottom:8.0px;">频道</div><div><div class="fl" style="width:80.0px;overflow:hidden;margin-bottom:4.0px;"><a href="https://www.vmall.com/huawei" target="_blank">华为专区</a></div><div class="fl" style="width:80.0px;overflow:hidden;margin-bottom:4.0px;"><a href="https://www.vmall.com/honor" target="_blank">荣耀专区</a></div><div class="fl" style="width:80.0px;overflow:hidden;margin-bottom:4.0px;"><a href="http://company.vmall.com/client.html" target="_blank">企业购</a></div></div></div><div class="fl" style="width:185.0px;margin-top:22.0px;margin-bottom:20.0px;"><div class="bold f16 black" style="margin-bottom:8.0px;">产品</div><div><div class="fl" style="width:80.0px;overflow:hidden;margin-bottom:4.0px;"><a href="https://www.vmall.com/list-36" target="_blank">手机</a></div><div class="fl" style="width:80.0px;overflow:hidden;margin-bottom:4.0px;"><a href="https://www.vmall.com/list-43" target="_blank">智能家居</a></div><div class="fl" style="width:80.0px;overflow:hidden;margin-bottom:4.0px;"><a href="https://www.vmall.com/list-40" target="_blank">平板&amp;笔记本</a></div><div class="fl" style="width:80.0px;overflow:hidden;margin-bottom:4.0px;"><a href="https://www.vmall.com/list-54" target="_blank">热销配件</a></div><div class="fl" style="width:80.0px;overflow:hidden;margin-bottom:4.0px;"><a href="https://www.vmall.com/list-59" target="_blank">智能穿戴</a></div></div></div><div class="fl" style="width:185.0px;margin-top:22.0px;margin-bottom:20.0px;"><div class="bold f16 black" style="margin-bottom:8.0px;">增值服务</div><div><div class="fl" style="width:80.0px;overflow:hidden;margin-bottom:4.0px;"><a href="https://www.vmall.com/recycle" target="_blank">以旧换新</a></div><div class="fl" style="width:80.0px;overflow:hidden;margin-bottom:4.0px;"><a href="https://www.vmall.com/order/tcsProductIndex" target="_blank">补购保障</a></div><div class="fl" style="width:80.0px;overflow:hidden;margin-bottom:4.0px;"><a href="https://www.vmall.com/order/batteryRenew" target="_blank">一口价换电池</a></div></div></div><div class="fl" style="width:185.0px;margin-top:22.0px;margin-bottom:20.0px;"><div class="bold f16 black" style="margin-bottom:8.0px;">会员</div><div><div class="fl" style="width:80.0px;overflow:hidden;margin-bottom:4.0px;"><a href="https://www.vmall.com/privilege" target="_blank">会员频道</a></div></div></div>
# </div>
# </div>
# </div>
# </li>
# <li class="downloadApp">
# <div class="s-dropdown" data-tpl="jTplDownloadApp">
# <div class="h">
# <a class="icon-dropdown">手机版</a>
# </div>
# </div>
# </li>
# <li>
# <div class="s-dropdown s-dropdown-minicart">
# <div class="h h-wide" id="header-toolbar-minicart">
# <a class="icon-minicart" href="/cart2?t=1581318515757timestamp" onclick="pushMyCartMsg()" rel="nofollow" target="blank" timetype="timestamp">
# <span>购物车(<span id="header-cart-total">0</span>)</span>
# </a>
# </div>
# <div class="b" id="header-toolbar-minicart-content">
# <!-- 2017-06-19-迷你购物车-start -->
# <div class="dropdown-minicart">
# <div class="minicart-pro-empty" id="minicart-pro-empty">
# <p><span class="icon-minicart"></span></p>
# <p id="cartInfo">您的购物车是空的，赶紧选购吧~</p>
# <a href="https://www.vmall.com">去逛逛吧</a>
# </div>
# <div class="minicart-pro-list minicart-pro-list-scroll hide" id="minicart-pro-list-block">
# <ul id="minicart-goods-list"></ul>
# <div class="minicart-pro-settleup" id="minicart-pro-settleup">
# <p>
# <span>总计：</span>
# <span><b id="micro-cart-totalPrice">¥ 0</b><s id="micro-cart-totalOriginPrice">¥ 0</s></span>
# </p>
# <a class="button-minicart" href="javascript:;" id="button-minicart-go2confirm" onclick="ec.minicart.confirm()">结算</a>
# <a class="button-minicart disabled" id="disbutton-minicart-go2confirm" style="display:none;">结算</a>
# </div>
# </div>
# </div>
# <!-- 2017-06-19-迷你购物车-end -->
# </div>
# </div>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <!-- 2017-06-19-捷径栏-end -->
# <textarea id="selectRegion-tips" style="display: none;">
# <!-- 20151105-全球语言弹出框-width:910px-start -->
# <div class="box-content">
# 	<div class="box-lan-choose">
# 						<dl>
# 				<dt>HUAWEI</dt>
# 				<dd class="box-button">
# 						<a class="box-choose" href="https://consumer.huawei.com/cz/?utm_source=vmall&amp;utm_medium=header">Czech</a>
# 						<a class="box-choose" href="https://consumer.huawei.com/fr/?utm_source=vmall&amp;utm_medium=header">France</a>
# 						<a class="box-choose" href="https://consumer.huawei.com/my/?utm_source=vmall&amp;utm_medium=header">Malaysia</a>
# 						<a class="box-choose" href="https://shop.huawei.com/mx/?utm_source=vmall&amp;utm_medium=header">Mexico</a>
# 						<a class="box-choose" href="https://shop.huawei.com/pl/?utm_source=vmall&amp;utm_medium=header">Poland</a>
# 						<a class="box-choose" href="https://shop.huawei.ru/?utm_source=vmall&amp;utm_medium=header">Russia</a>
# 						<a class="box-choose" href="https://consumer.huawei.com/sa/?utm_source=vmall&amp;utm_medium=header">Saudi Arabia</a>
# 						<a class="box-choose" href="https://consumer.huawei.com/ae/?utm_source=vmall&amp;utm_medium=header">United Arab Emirates</a>
# 				</dd>
# 			</dl>
# 				<dl class="box-lan-choose-area">
# 				<dt>HONOR</dt>
# 				<dd class="box-button">
# 						<a class="box-choose" href="https://www.hihonor.com/de/">Germany</a>
# 						<a class="box-choose" href="https://www.hihonor.com/fr/">France</a>
# 						<a class="box-choose" href="https://www.hihonor.com/in/">India</a>
# 						<a class="box-choose" href="https://www.hihonor.com/it/">Italia</a>
# 						<a class="box-choose" href="https://www.hihonor.com/my/">Malaysia</a>
# 						<a class="box-choose" href="https://shop.huawei.ru/">Russia</a>
# 						<a class="box-choose" href="https://www.hihonor.com/sa/">Saudi Arabia</a>
# 						<a class="box-choose" href="https://www.hihonor.com/ae/">United Arab Emirates</a>
# 						<a class="box-choose" href="https://www.hihonor.com/uk/">United Kingdom</a>
# 						<a class="box-choose" href="https://www.hihonor.com/es/">Spain</a>
# 				</dd>
# 			</dl>
# 	</div>
# </div>
# <!-- 20151105-全球语言弹出框-width:910px-end -->
# </textarea>
# <input id="context" type="hidden" value=""/>
# <input id="domainUc" type="hidden" value="https://member.vmall.com"/>
# <input id="vmall_index" type="hidden" value="vmall_index"/>
# <script type="text/javascript">
#
# function pushLoginMsg(name, subName) {
#   ec.dapClick(300000201, {
#     "name": name,
#     "subName": subName,
#     "click": "1"
#   });
# }
#
# function pushLoginMsgInfoPerson(name, subName) {
#   ec.account.afterLogin(function() {});
#   ec.dapClick(300000201, {
#     "name": name,
#     "subName": subName,
#     "click": "1"
#   });
# }
#
# function pushHeaderMsgPriority(name, url) {
#   ec.account.afterLogin(function() {
#     ec.redirectTo("https://www.vmall.com/priority");
#   });
#   ec.dapClick(300000101, {
#     "name": name,
#     "URL": url,
#     "click": "1",
#   });
# }
#
# function pushHeaderMsg(name, url) {
#   ec.dapClick(300000101, {
#     "name": name,
#     "URL": url,
#     "click": "1",
#   });
# }
#
# $('.shortcut .s-dropdown').each(function() {
# 	var catname = $(this).find('.icon-dropdown').text();
# 	var mdap = function(name, url, category) {
# 		ec.dapClick(300000101, {
# 				name: name,
# 				URL: url,
# 				category: category,
# 				click: 1
# 		});
# 	};
# 	if ('客户服务' === catname || '更多精彩' === catname) {
# 		$(this).find('dt a').bind('click', function() {
# 			mdap($(this).text(), $(this).attr('href'), catname);
# 		});
# 	}
# 	if ('网站导航' === catname) {
# 		$(this).find('dd a').bind('click', function() {
# 			mdap($(this).text(), $(this).attr('href'), catname);
# 		});
# 	}
# });
#
# checkIEVersion();
# ec.mediaPath = "https://res.vmallres.com/pimages/";
# </script>
# <textarea class="hide" id="micro-cart-tpl">
# <!--#macro microCartList data-->
# <!--#list data.itemInfos as item-->
# 		<!--#var classChoose='';-->
#
#
#
#
#
#             <!--#var skuId='#'+item.skuId;-->
#
#
#
#              <!--#if (item.subItems && item.subItems.length > 0)-->
#             <!--#list item.subItems as sub-->
#  				<!--#if ((classChoose) && (classChoose != "true")  )-->
#    					<!--#var  classChoose='false';-->
#
#    				<!--/#if-->
#            		<!--#if (sub.itemType == 'S1' || sub.itemType == 'S6' || sub.itemType == 'S15')-->
#         				<!--#var  classChoose='true';-->
#    					 <!--#else-->
#             	<!--/#if-->
#            		<!--#if (sub.itemType == 'G' )-->
#         				<!--#var gGift='true';-->
#             	<!--/#if-->
#             	<!--#if (sub.itemType == 'J' )-->
#         				<!--#var jBuy='true';-->
#             	<!--/#if-->
# 	        <!--/#list-->
# 	       <!--/#if-->
#
# 	        <!--#if (classChoose == 'true' )-->
#         	    <li class="minicart-pro-item minicart-pro-item-suit &lt;!--#if ( (item.show))--&gt;disabled&lt;!--/#if--&gt;">
#             <!--#else-->
#                 </li><li class="minicart-pro-item &lt;!--#if ( (item.show)) --&gt;disabled&lt;!--/#if--&gt;">
#             <!--/#if-->
#
#             <div class="pro-info clearfix">
#            	<!--#if (item.itemType=='B')-->
#
#
#                      <!--#if (item.invalidCauseReason == 0) -->
#                         <div class="p-choose"><i class="&lt;!--#if (item.selected)--&gt;icon-choose&lt;!--#else--&gt;icon-choose-normal&lt;!--/#if--&gt;" data-itemid="{#item.itemId}" id="icon-choose-{#item.itemkd}" onclick="ec.minicart.click(this)" type="{#item.itemType}" value="{#item.itemCode}"></i></div>
#                         <input class="hide" data-itemid="{#item.itemId}" id="checkbox-{#item.itemkd}" name="bundleIds" type="checkbox" value="{#item.itemCode}"/>checked="checked"<!--/#if--> /&gt;
#                         <input class="hide" data-type="{#item.itemType}" id="quantity-{#item.itemCode}" type="text" value="{#item.qty}"/>checked="checked"<!--/#if--> /&gt;
#                     <!--#elseif ((item.invalidCauseReason == 7)&&( !item.numblimit   )&&(!item.show) )-->
#                          <div class="p-choose"><i class="&lt;!--#if (item.selected)--&gt;icon-choose&lt;!--#else--&gt;icon-choose-normal&lt;!--/#if--&gt;" data-itemid="{#item.itemId}" id="icon-choose-{#item.itemkd}" onclick="ec.minicart.click(this)" type="{#item.itemType}" value="{#item.itemCode}"></i></div>
#                         <input class="hide" data-itemid="{#item.itemId}" id="checkbox-{#item.itemkd}" name="bundleIds" type="checkbox" value="{#item.itemCode}"/>checked="checked"<!--/#if--> /&gt;
#                         <input class="hide" data-type="{#item.itemType}" id="quantity-{#item.itemCode}" type="text" value="{#item.qty}"/>checked="checked"<!--/#if--> /&gt;
#                     <!--#else-->
#                         <div class="p-choose"><i class="icon-choose-normal" id="icon-choose-{#item.itemCode}"></i></div>
#                         <input class="hide" id="checkbox-{#item.itemCode}" name="bundleIds" type="checkbox" value="{#item.itemCode}"/>
#                         <input class="hide" data-type="{#item.itemType}" id="quantity-{#item.itemCode}" type="text" value="{#item.qty}"/>
#                     <!--/#if-->
#
#                     <div class="p-img">
#                         <a href="/product/{#item.photoId}.html{#skuId}" onclick="pushCartProMsg('{#skuId}','/product/{#item.photoId}.html{#skuId}','{#item_index+1}')" target="_blank" title="">
#                             <img alt="{#item.itemName}" src="https://res.vmallres.com/pimages/{#item.photoPath}78_78_{#item.photoName}"/>
#                         </a>
#                     </div>
#
#                     <div class="p-name">
#                         <a href="/product/{#item.photoId}.html{#skuId}" onclick="pushCartProMsg('{#skuId}','/product/{#item.photoId}.html{#skuId}','{#item_index+1}')" target="_blank" title="{#item.itemName}">{#item.itemName}</a>
#                     </div>
#
#
#             <!--#else-->
#                     <!--#if ((item.invalidCauseReason == 0) &&(!item.bnumblimit) &&(!item.numblimit)) -->
#
#                         <div class="p-choose">
#                         <!--#if (item.itemType == "P") -->
#                         <i class="&lt;!--#if (item.selected) --&gt;icon-choose&lt;!--#else--&gt;icon-choose-normal&lt;!--/#if--&gt;" data-itemid="{#item.itemId}" id="icon-choose-{#item.itemkd}" onclick="ec.minicart.click(this)" type="{#item.itemType}" value="{#item.skuId}"></i>
#                          <input class="hide" data-itemid="{#item.itemId}" data-scode="{#item.itemCode}" id="checkbox-{#item.itemkd}" name="skuIds" type="checkbox" value="{#item.skuId}"/>checked="checked"<!--/#if-->&gt;
#             		  <!--#else-->
#                         <i class="&lt;!--#if (item.selected) --&gt;icon-choose&lt;!--#else--&gt;icon-choose-normal&lt;!--/#if--&gt;" data-itemid="{#item.itemId}" id="icon-choose-{#item.itemkd}" onclick="ec.minicart.click(this)" type="{#item.itemType}" value="{#item.skuId}"></i>
#                         <input class="hide" data-itemid="{#item.itemId}" data-scode="{#item.itemCode}" id="checkbox-{#item.itemkd}" name="skuIds" type="checkbox" value="{#item.skuId}"/>checked="checked"<!--/#if-->&gt;
#                         <!--/#if-->
#                         </div>
#
#                         <input class="hide" data-type="{#item.itemType}" id="quantity-{#item.skuId}" type="text" value="{#item.qty}"/>checked="checked"<!--/#if--> /&gt;
#
#                      <!--#elseif ((item.invalidCauseReason == 7)&&( !item.numblimit  )&&(!item.show) )-->
#
#                                   <div class="p-choose">
#                         <!--#if (item.itemType == "P") -->
#                         <i class="&lt;!--#if (item.selected) --&gt;icon-choose&lt;!--#else--&gt;icon-choose-normal&lt;!--/#if--&gt;" data-itemid="{#item.itemId}" id="icon-choose-{#item.itemkd}" onclick="ec.minicart.click(this)" type="{#item.itemType}" value="{#item.skuId}"></i>
#                          <input class="hide" data-itemid="{#item.itemId}" data-scode="{#item.itemCode}" id="checkbox-{#item.itemkd}" name="skuIds" type="checkbox" value="{#item.skuId}"/>checked="checked"<!--/#if-->&gt;
#             		  <!--#else-->
#                         <i class="&lt;!--#if (item.selected) --&gt;icon-choose&lt;!--#else--&gt;icon-choose-normal&lt;!--/#if--&gt;" data-itemid="{#item.itemId}" id="icon-choose-{#item.itemkd}" onclick="ec.minicart.click(this)" type="{#item.itemType}" value="{#item.skuId}"></i>
#                         <input class="hide" data-itemid="{#item.itemId}" data-scode="{#item.itemCode}" id="checkbox-{#item.itemkd}" name="skuIds" type="checkbox" value="{#item.skuId}"/>checked="checked"<!--/#if-->&gt;
#                         <!--/#if-->
#                         </div>
#
#                         <input class="hide" data-type="{#item.itemType}" id="quantity-{#item.skuId}" type="text" value="{#item.qty}"/>checked="checked"<!--/#if--> /&gt;
#
#                     <!--#else-->
#                         <div class="p-choose"><i class="icon-choose-normal" id="icon-choose-{#item.skuId}"></i></div>
#                         <input class="hide" id="checkbox-{#item.skuId}" name="skuIds" type="checkbox" value="{#item.skuId}"/>
#                         <input class="hide" data-type="{#item.itemType}" id="quantity-{#item.skuId}" type="text" value="{#item.qty}"/>
#                     <!--/#if-->
#
#         			<!--#if ((item.attrsMap)&&(item.attrsMap.package_code)) -->
#         			 <input class="hide" data-scode="&lt;!--#list item.subItems as sku--&gt;&lt;!--#if ((sku.itemType=='B')||(sku.itemType=='P'))--&gt;{#sku.itemCode},&lt;!--/#if--&gt;&lt;!--/#list--&gt;" id="bundle-{#item.itemkd}" name="newBundle" type="checkbox" value="{#item.attrsMap.package_code}"/>
#         			<!--/#if-->
#
#                     <!--#if ((item.attrsMap)&&(item.attrsMap.dp_package_code)) -->
#                     <input class="hide" data-dpcode="{#item.attrsMap.dp_package_code}" id="dpPackage-{#item.itemkd}" name="dpPackage" type="hidden" value="&lt;!--#list item.subItems as sku--&gt;&lt;!--#if (sku.itemType=='DP')--&gt;{#sku.itemCode},{#sku.attrsMap.dp_group}|&lt;!--/#if--&gt;&lt;!--/#list--&gt;"/>
#                     <!--/#if-->
#
#                  	 <div class="p-img">
#                         <a href="/product/{#item.productId}.html{#skuId}" onclick="pushCartProMsg('{#skuId}','/product/{#item.productId}.html{#skuId}','{#item_index+1}')" target="_blank" title="">
#                             <img alt="{#item.itemName}" src="https://res.vmallres.com/pimages/{#item.photoPath}78_78_{#item.photoName}"/>
#                         </a>
#                     </div>
#
#                     <div class="p-name">
#                         <a href="/product/{#item.productId}.html{#skuId}" onclick="pushCartProMsg('{#skuId}','/product/{#item.productId}.html{#skuId}','{#item_index+1}')" target="_blank" title="{#item.itemName}">{#item.itemName}</a>
#                     </div>
#                  <!--/#if-->
#                     <div class="p-dec">
#                         <span class="p-slogan">
#
#                         </span>
#                     </div>
#                     <div class="p-status">
#
#                         <!--#if (gGift == "true") -->
#                         <!--#list item.subItems as gif-->
#                         <!--#if (gif.itemType=="G")-->
#                         <!--#if ((gif.attrsMap)&&(gif.attrsMap.g_group)) -->
#                         <input class="hide" data-group="{#gif.attrsMap.g_group}" name="giftId" type="checkbox" value="{#gif.itemCode}"/>
#                         <!--#else-->
#                         <input class="hide" data-group="" name="giftId" type="checkbox" value="{#gif.itemCode}"/>
#                         <!--/#if-->
#                         <!--/#if-->
#                         <!--/#list-->
#                         <!--/#if-->
#
#                       	<!--#if (   (item.showP)&&( (item.invalidCauseReason==0) ||  ( (item.invalidCauseReason==7)  && (  !item.numblimit  )  )  )    ) -->
#  						<div class="p-tags">此商品已失效</div>
#                         <!--#else-->
#                         <!--#if (item.invalidCauseReason == 1) -->
#                         <div class="p-tags">此商品已失效</div>
#                         <!--#elseif (item.invalidCauseReason == 2) -->
#                         <div class="p-tags">此商品已失效 </div>
#                         <!--#elseif (item.invalidCauseReason == 3) -->
#                         <div class="p-tags">此商品已失效 </div>
#                         <!--#elseif (item.invalidCauseReason == 4) -->
#                         <div class="p-tags">此商品已失效 </div>
#                         <!--#elseif (item.invalidCauseReason == 5) -->
#                         <div class="p-tags">此商品暂不可购买 </div>
#                         <!--#elseif (item.invalidCauseReason == 6) -->
#                         <div class="p-tags">此商品暂时缺货 </div>
#                         <!--#elseif (item.invalidCauseReason == 7) -->
#                         <div class="p-tags">此商品限购{#item.invalidCauseLeftValue}件</div>
#                         <!--#elseif (item.invalidCauseReason == 8) -->
#                         <div class="p-tags">超过内购限额 </div>
#                         <!--#elseif (item.invalidCauseReason == 9) -->
#                         <div class="p-tags">此商品不在本渠道销售</div>
#                         <!--#elseif (item.invalidCauseReason == 10) -->
#                         <div class="p-tags">此商品已失效 </div>
#                         <!--#elseif (item.invalidCauseReason == 101) -->
#                         <div class="p-tags">此套餐已失效 </div>
#                         <!--#elseif (item.invalidCauseReason == 106) -->
#                         <div class="p-tags">此套餐暂时缺货 </div>
#                         <!--/#if-->
#                         <!--/#if-->
#
#                         <div class="p-price">
#                             <!--#if (item.salePrice != item.originalPrice) --><s>¥ {#item.originalPrice.toFixed(2)}</s>  <!--/#if-->
#                             <b>¥ {#item.salePrice.toFixed(2)}</b><strong><em>x</em><span>{#item.qty}</span></strong>
#                         </div>
#                     </div>
#                 </div>
#
# 					<!--#if ((item.itemType=='B')||(item.itemType=='P'))-->
# 					<div class="p-pack &lt;!--#if (item.show) --&gt;disabled&lt;!--/#if--&gt;">
#                     <span class="p-mini-tag-suit">套餐</span>
#                     <a href="javascript:;" title="&lt;!--#list item.subItems as sku--&gt;&lt;!--#if ((sku.itemType=='B')||(sku.itemType=='P'))--&gt;{#sku.itemName}x{#sku.qty}&lt;!--/#if--&gt;&lt;!--/#list--&gt;">
#                         <!--#list item.subItems as sku-->
#                         <!--#if ((sku.itemType=='B')||(sku.itemType=='P'))-->
#                         <span>
#                         {#sku.itemName}<em>x{#sku.qty}</em>
# 						</span>
# 						<!--/#if-->
#                         <!--/#list-->
#                     	</a>
#                 	</div>
# 					<!--/#if-->
#
# 				<!--#if (classChoose=='true')-->
#                 <div class="pro-other clearfix" id="{#classChoose}">
#                     <ol>
#                         <!--#list item.subItems as sub-->
#                         <!--#if (sub.itemType == "S15") -->
#                         <li class="&lt;!--#if (sub.invalidCauseReason != 0) --&gt;disabled&lt;!--/#if--&gt;">
#                             <div class="p-title">
#                                 <span class="p-mini-tag-extend">无忧服务</span>{#sub.itemName}
#                             </div>
#                             <input class="hide" data-id="{#sub.itemId}" data-scode="{#sub.itemCode}" name="ucareIds" type="checkbox" value="{#sub.skuId}"/>
#                             <div class="p-price"><b>¥ {#sub.salePrice.toFixed(2)}</b><strong><em>x</em><span>{#item.qty}</span></strong></div>
#                         </li>
#                         <!--/#if-->
#                         <!--/#list-->
#
#                         <!--#list item.subItems as sub-->
#                         <!--#if (sub.itemType == "S6") -->
#                         <li class="&lt;!--#if (sub.invalidCauseReason != 0) --&gt;disabled&lt;!--/#if--&gt;">
#                             <div class="p-title">
#                                 <span class="p-mini-tag-extend">碎屏保</span>{#sub.itemName}
#                             </div>
#                             <input class="hide" data-id="{#sub.itemId}" data-scode="{#sub.itemCode}" name="accidentIds" type="checkbox" value="{#sub.skuId}"/>
#                             <div class="p-price"><b>¥ {#sub.salePrice.toFixed(2)}</b><strong><em>x</em><span>{#item.qty}</span></strong></div>
#                         </li>
#                         <!--/#if-->
#                         <!--/#list-->
#
#                         <!--#list item.subItems as sub-->
#                         <!--#if (sub.itemType == "S1") -->
#                         <li class="&lt;!--#if (sub.invalidCauseReason != 0) --&gt;disabled&lt;!--/#if--&gt;">
#                             <div class="p-title">
#                                 <span class="p-mini-tag-long">延保</span>{#sub.itemName}
#                             </div>
#                             <input class="hide" data-id="{#sub.itemId}" data-scode="{#sub.itemCode}" name="extendIds" type="checkbox" value="{#sub.skuId}"/>
#                             <div class="p-price"><b>¥ {#sub.salePrice.toFixed(2)}</b><strong><em>x</em><span>{#item.qty}</span></strong></div>
#                         </li>
#                         <!--/#if-->
#                         <!--/#list-->
#       				</ol>
#       			</div>
# 				<!--/#if-->
#
# 				<!--#if (gGift=="true")-->
#                 <input g="" id="gift_sbomCodes_{#item.skuId}" type="hidden" value="&lt;!--#list item.subItems as gift--&gt;&lt;!--#if (gift.itemType == "/>{#gift.skuId},<!--/#if--><!--/#list-->" /&gt;
#                 <div class="p-pack">
#                     <span class="p-mini-tag-suit">配</span>
#                     <a g="" href="javascript:;" style="cursor: default;" title="&lt;!--#list item.subItems as gift--&gt;&lt;!--#if (gift.itemType == ">{#gift.itemName}x{#gift.qty*item.qty},<!--/#if--><!--/#list-->"&gt;
#                         <!--#list item.subItems as gift--><!--#if (gift.itemType == "G") -->
#                         <span class="&lt;!--#if (gift.invalidCauseReason != 0) --&gt;disabled&lt;!--/#if--&gt;">
#                         {#gift.itemName}<em>x{#gift.qty*item.qty}</em>
#                         </span>
# 						<!--/#if-->
#                         <!--/#list-->
#                     </a>
#                 </div>
#                 <!--/#if-->
#
#                 <!--#if (item.itemType=='DP')-->
#                 <div class="pro-other clearfix">
#                     <ol>
#                         <!--#list item.subItems as sub-->
#                         <!--#if (sub.itemType == "DP") -->
#                         <li class="&lt;!--#if ((sub.Jlost)||(sub.invalidCauseReason!=0)) --&gt;disabled&lt;!--/#if--&gt;">
#                             <div class="p-title p-add">
#                                 <span class="p-mini-tag-suit">搭配</span>{#sub.itemName}
#                             </div>
#                             <div class="p-price">
#                                 <!--#if (sub.salePrice != sub.originalPrice) --><s>¥ {#sub.originalPrice.toFixed(2)}</s>  <!--/#if-->
#                                 <b>¥ {#sub.salePrice.toFixed(2)}</b><strong><em>x</em><span>{#sub.qty}</span></strong>
#                             </div>
#                         </li>
#                         <!--/#if-->
#                         <!--/#list-->
#                     </ol>
#                 </div>
#                 <!--/#if-->
#
#                 <!--#if (jBuy=='true')-->
#                 <div class="pro-other clearfix">
#                     <ol>
#                         <!--#if (jBuy=="true")-->
#                         <input id="preferIds_{#item.skuId}" j="" type="hidden" value="&lt;!--#list item.subItems as ea--&gt;&lt;!--#if (ea.itemType == "/>{#ea.itemCode},<!--/#if--><!--/#list-->"
#                         skuids="<!--#list item.subItems as ea--><!--#if (ea.itemType == "J") -->{#ea.skuId},<!--/#if--><!--/#list-->"
#                         newId="<!--#list item.subItems as ea--><!--#if (ea.itemType == "J") -->{#ea.itemId},<!--/#if--><!--/#list-->" /&gt;
#                         <!--/#if-->
#
#                         <!--#list item.subItems as sub-->
#                         <!--#if (sub.itemType == "J") -->
#                         <li class="&lt;!--#if ((sub.Jlost)||(sub.invalidCauseReason!=0)) --&gt;disabled&lt;!--/#if--&gt;">
#                             <div class="p-title p-add">
#                                 <span class="p-mini-tag-extend">加价购</span>{#sub.itemName}
#                             </div>
#                             <div class="p-price">
#                                 <!--#if (sub.salePrice != sub.originalPrice) --><s>¥ {#sub.originalPrice.toFixed(2)}</s>  <!--/#if-->
#                                 <b>¥ {#sub.salePrice.toFixed(2)}</b><strong><em>x</em><span>{#sub.qty}</span></strong>
#                             </div>
#                         </li>
#                         <!--/#if-->
#                         <!--/#list-->
#                     </ol>
#                 </div>
#                 <!--/#if-->
#
#             </li>
#
#       <!--/#list-->
# <!--/#macro-->
# </textarea>
# <textarea class="hide" id="ec-binding-phone">
#     <div class="ec-binding-phone-box hide" id="ec-binding-phone-1">
#         <!-- 20141011-绑定安全手机号提示-start -->
#         <div class="box-phone01">
#             <div class="h">
#                 <i></i>
#             </div>
#             <div class="b">
#                 <p class="title">绑定手机号码</p>
#                 <p>为了给您提供更好的服务，建议您将登录的邮箱帐号进行手机号码绑定，绑定后邮箱帐号和绑定的手机号码都可以作为登录帐号，<em class="red">不绑定将不能提交订单。</em></p>
#             </div>
#         </div>
#         <div class="box-button">
#             <a class="box-ok" href="javascript:;" id="ec-binding-phone-url-1"><span>立即绑定</span></a>
#         </div>
#         <!-- 20141011-绑定安全手机号提示-end -->
#     </div>
#     <div class="ec-binding-phone-box hide" id="ec-binding-phone-2">
#         <!-- 20141424-绑定安全手机号提示-start -->
#         <div class="box-phone01">
#             <div class="h">
#                 <i></i>
#             </div>
#             <div class="b">
#                 <p class="title">绑定手机号码</p>
#                 <p>请您在新打开的页面中完成绑定安全手机号操作，完成绑定后请根据您的情况点击下面的按钮。</p>
#             </div>
#         </div>
#         <div class="box-button">
#             <a class="box-cancel" href="javascript:;" id="ec-binding-phone-url-2"><span>重新绑定</span></a>
#             <a class="box-ok" href="javascript:;" onclick="ec.binding.resetShow()"><span>绑定成功</span></a>
#         </div>
#         <!-- 20141424-绑定安全手机号提示-end -->
#     </div>
#     <div class="ec-binding-phone-box hide" id="ec-binding-phone-3">
#         <!-- 20141424-安全手机号绑定提示失败-start -->
#         <div class="box-phone01">
#             <div class="h">
#                 <i></i>
#             </div>
#             <div class="b">
#                 <p class="title">对不起，您未成功绑定手机号</p>
#                 <p>为了您在商城正常购物、保护您的权益，请您绑定一个手机号码以享受华为商城的所有服务。</p>
#             </div>
#         </div>
#         <div class="box-button">
#             <a class="box-ok" href="javascript:;" id="ec-binding-phone-url-3" onclick="ec.binding.showOk()"><span>立即绑定</span></a>
#         </div>
#         <!-- 20141424-安全手机号绑定提示失败-end -->
#     </div>
#     <div class="ec-binding-phone-box hide" id="ec-binding-phone-4">
#         <!-- 20150824-手机号绑定未绑定-start -->
#         <div class="box-phone01">
#             <div class="h">
#                 <i></i>
#             </div>
#             <div class="b">
#                 <p class="title">绑定手机号码</p>
#                 <p>为了给您提供更好的服务，建议您将登录的邮箱帐号进行手机号码绑定，绑定后邮箱帐号和绑定的手机号码都可以作为登录帐号；<em class="red">自</em><em class="red" id="bindEndDate4State4"></em><em class="red">号起，若不绑定将不能提交订单。</em></p>
#             </div>
#         </div>
#         <div class="box-button">
#             <a class="box-cancel" href="javascript:;" onclick="ec.binding.closeState4();"><span>下次再说</span></a>
#             <a class="box-ok" href="javascript:;" id="ec-binding-phone-url-4"><span>立即绑定</span></a>
#         </div>
#         <!-- 20150824-安全手机号绑定提示失败-end -->
#     </div>
#     <div class="ec-binding-phone-box hide" id="ec-binding-phone-5">
#         <!-- 20141424-安全手机号绑定提示失败-start -->
#         <div class="box-phone01">
#             <div class="h">
#                 <i></i>
#             </div>
#             <div class="b">
#                 <p class="title">绑定手机号码</p>
#                 <p>您输入的手机已被注册，您可以选择使用手机号重新登录或者重新绑定手机！</p>
#             </div>
#         </div>
#         <div class="box-button">
#             <a class="box-cancel" href="https://www.vmall.com/account/login" id="ec-binding-phone-reLogin-5"><span>重新登录</span></a>')
#             <a class="box-ok" href="javascript:;" id="ec-binding-phone-url-5"><span>重新绑定</span></a>
#         </div>
#         <!-- 20141424-安全手机号绑定提示失败-end -->
#     </div>
# </textarea>
# <textarea class="hide" id="jTplDownloadApp">
# <div class="b"><div class="dropdown-code"><div class="clearfix dropdown-code-detail">  <a href="https://www.vmall.com/appdownload" target="_blank"><img class="code-img" src="https://res.vmallres.com/pimages//pages/cdnImages/FWETOIrFlCrX4xuB8E16.png"/></a><div class="code-info"><h2>华为商城APP</h2><p class="red">新人专享好礼<br/>最高5000积分</p><span class="icon-andrid fl mgr-5"></span><span class="icon-ios fl mgr-5"></span><span class="icon-wechat fl"></span>      </div>  </div>    <div class="clearfix dropdown-code-detail">      <a><img class="code-img" src="https://res.vmallres.com/pimages/sale/2018-11/20181116180507506.jpg"/></a>  <div class="code-info">        <h2>华为商城公众号</h2><p>微信扫一扫</p><span class="icon-wechat"></span>      </div>    </div>    <div class="clearfix dropdown-code-detail"> <a><img class="code-img" src="https://res.vmallres.com/pimages//sale/2018-12/6Y7SW4v4hnJ9kl9fDC9d.jpg"/></a> <div class="code-info">  <h2>微信小程序</h2><span class="icon-wechat"></span>  </div>    </div>  </div></div>
# </textarea><!-- 2017-02-15-头部-start -->
# <div class="header">
# <div class="layout">
# <div class="left">
# <!-- 2017-02-15-logo-start -->
# <div class="logo"><a href="https://www.vmall.com/index.html" onclick="pushLogoClickMsg('https://res.vmallres.com/pimages//sale/2018-11/x9a6U8WW0bhrA7u0FIlY.png','https\x3A\x2F\x2Fwww.vmall.com\x2Findex.html')" title="Vmall.com - 华为商城"><img alt="Vmall.com - 华为商城" src="https://res.vmallres.com/pimages//sale/2018-11/x9a6U8WW0bhrA7u0FIlY.png"/></a></div>
# <!-- 2017-02-15-logo-end -->
# <!-- 2017-06-19-导航-start -->
# <div class="naver">
# <ul class="clearfix" id="naver">
# <li data-id="0" id="zxnav_0">
# <a href="list-36" target="_blank"><span>手机</span></a>
# <input autocomplete="off" id="zxnav_0_flag" type="hidden" value="no"/>
# <input autocomplete="off" id="zxnav_0_name" type="hidden" value="手机"/>
# </li>
# <li data-id="1" id="zxnav_1">
# <a href="list-40" target="_blank"><span>笔记本 &amp; 平板</span></a>
# <input autocomplete="off" id="zxnav_1_flag" type="hidden" value="no"/>
# <input autocomplete="off" id="zxnav_1_name" type="hidden" value="笔记本 &amp; 平板"/>
# </li>
# <li data-id="2" id="zxnav_2">
# <a href="list-59" target="_blank"><span>智能穿戴 &amp; VR</span></a>
# <input autocomplete="off" id="zxnav_2_flag" type="hidden" value="no"/>
# <input autocomplete="off" id="zxnav_2_name" type="hidden" value="智能穿戴 &amp; VR"/>
# </li>
# <li data-id="3" id="zxnav_3">
# <a href="list-43" target="_blank"><span>智能家居 &amp; 智慧屏</span></a>
# <input autocomplete="off" id="zxnav_3_flag" type="hidden" value="no"/>
# <input autocomplete="off" id="zxnav_3_name" type="hidden" value="智能家居 &amp; 智慧屏"/>
# </li>
# <li data-id="4" id="zxnav_4">
# <a href="list-54" target="_blank"><span>热销配件</span></a>
# <input autocomplete="off" id="zxnav_4_flag" type="hidden" value="no"/>
# <input autocomplete="off" id="zxnav_4_name" type="hidden" value="热销配件"/>
# </li>
# <li data-id="5" id="zxnav_5">
# <a href="list-34" target="_blank"><span>增值服务 &amp; 其他</span></a>
# <input autocomplete="off" id="zxnav_5_flag" type="hidden" value="no"/>
# <input autocomplete="off" id="zxnav_5_name" type="hidden" value="增值服务 &amp; 其他"/>
# </li>
# </ul>
# </div>
# <div class="naver-sub hide" id="naver-sub-category">
# <div class="naver-sub-wrap hide" id="naverSub00">
# <div class="p-title clearfix">
# <div class="s1 fl">
# <a class="" href="list-36" target="_blank">全部手机</a>
# </div>
# <div class="s2 fl clearfix">
# <input id="child_name" type="hidden" value="HUAWEI Mate系列"/>
# <input id="child_status" type="hidden" value="1"/>
# <input id="child_type" type="hidden" value="1"/>
# <a class="fl" href="list-76" target="_blank">HUAWEI Mate系列</a>
# <input id="child_name" type="hidden" value="HUAWEI P系列"/>
# <input id="child_status" type="hidden" value="1"/>
# <input id="child_type" type="hidden" value="1"/>
# <a class="fl" href="list-285" target="_blank">HUAWEI P系列</a>
# <input id="child_name" type="hidden" value="HUAWEI nova系列"/>
# <input id="child_status" type="hidden" value="1"/>
# <input id="child_type" type="hidden" value="1"/>
# <a class="fl" href="list-277" target="_blank">HUAWEI nova系列</a>
# <input id="child_name" type="hidden" value="华为畅享系列"/>
# <input id="child_status" type="hidden" value="1"/>
# <input id="child_type" type="hidden" value="1"/>
# <a class="fl" href="list-275" target="_blank">华为畅享系列</a>
# <input id="child_name" type="hidden" value="荣耀 V系列"/>
# <input id="child_status" type="hidden" value="1"/>
# <input id="child_type" type="hidden" value="1"/>
# <a class="fl" href="list-75" target="_blank">荣耀 V系列</a>
# <input id="child_name" type="hidden" value="荣耀 HONOR系列"/>
# <input id="child_status" type="hidden" value="1"/>
# <input id="child_type" type="hidden" value="1"/>
# <a class="fl" href="list-666" target="_blank">荣耀 HONOR系列</a>
# <input id="child_name" type="hidden" value="荣耀 X系列"/>
# <input id="child_status" type="hidden" value="1"/>
# <input id="child_type" type="hidden" value="1"/>
# <a class="fl" href="list-668" target="_blank">荣耀 X系列</a>
# <input id="child_name" type="hidden" value="荣耀 Play系列"/>
# <input id="child_status" type="hidden" value="1"/>
# ...
# <div class="popup-button-area"><a class="box-button-style-1" href="javascript:;" id="ec_ui_confirm_new_yes"><span>是</span></a><a class="box-button-style-1" href="javascript:;" id="ec_ui_confirm_new_no"><span>否</span></a></div>
# </div>
# <div class="f"><s class="icon-arrow-down-new"></s></div>
# </div>
# <!--提示对话框-->
# <div class="popup-area popup-define-area hide" id="ec_ui_tips">
# <div class="b">
# <p class="tac" id="ec_ui_tips_msg"></p>
# <div class="popup-button-area tac"><a class="button-action-yes" href="javascript:;" id="ec_ui_tips_yes" title="确定"><span>确定</span></a></div>
# </div>
# <div class="f"><s class="icon-arrow-down"></s></div>
# </div>
# <!-- 2018-10-26-悬浮工具栏-start -->
# <!-- 20170518-商品简介-按钮-start -->
# <div class="hungBar j-hungBar">
# <div class="hungBar-content">
# <div class="product-support">
# <ul>
# <li>
# <a class="product-button-oldnew" href="https://www.vmall.com/recycle" target="_blank"></a>
# <div class="product-support-detial product-oldnew-detail hide">
# <div class="product-support-detialmain">
# <label>以旧换新，</label><a href="https://www.vmall.com/recycle" style="color:red" target="_blank">限时领券，享回收加价补贴</a>
# </div>
# </div>
# </li>
# <li>
# <a class="product-button-code"></a>
# <div class="product-support-detial product-code-detail hide">
# <div class="product-support-detialmain">
# <p>用手机扫码进行购买</p>
# <div id="product_wap"></div>
# </div>
# </div>
# </li>
# </ul>
# </div>
# <div class="hungBar-common">
# <a class="hungBar-cart" href="/cart2" onclick="pushRightHelpMsg(1)" target="_blank" timetype="timestamp"><span style="display:none;"></span><i>购物车</i></a>
# <a class="hungBar-service" href="javascript:;" id="tools-nav-service-robotim" onclick="pushRightHelpMsg(2)" target="_blank"><i>在线客服</i></a>
# <a class="hungBar-feedback" href="javascript:;" id="tools-nav-survery" onclick="ec.survery.open();pushRightHelpMsg(3)"><i>意见反馈</i></a>
# <a class="hungBar-top" href="javascript:;" id="hungBar-top"><i>返回顶部</i></a>
# </div>
# </div>
# </div>
# <!-- 2018-10-26-悬浮工具栏-end -->
# <!--意见反馈box-->
# <div class="ol_box_4 hide" id="survery-box" style="width:600px;">
# <div class="box-ct">
# <div class="box-header">
# <div class="box-tl"></div>
# <div class="box-tc">
# <div class="box-tc1"></div>
# <div class="box-tc2"><a class="box-close" href="javascript:;" onclick="ec.survery.close();" title="关闭"></a><span class="box-title">意见反馈</span></div>
# </div>
# <div class="box-tr"></div>
# </div>
# <table border="0" cellpadding="0" cellspacing="0" width="100%">
# <tbody>
# <tr>
# <td class="box-cl"></td>
# <td class="box-cc">
# <div class="box-content">
# <!-- -表单-意见反馈-start -->
# <div class="form-feedback-area">
# <div class="b">
# <div class="form-edit-area">
# <form autocomplete="off" id="form-feedback">
# <div class="form-edit-table">
# <table border="0" cellpadding="0" cellspacing="0">
# <tbody>
# <tr>
# <td>
# <select id="surverytype" name="type">
# <option>请选择疑问类型</option>
# <option>商品质量（手机、平板等软、硬件质量）</option>
# <option>商品缺货</option>
# <option>物流发货（发货快慢、发错货、送件人态度等）</option>
# <option>售后服务（服务网点、维修、退换货、客服）</option>
# <option>网站问题（商城功能失效、不好用等）</option>
# <option>其他问题</option>
# </select>
# </td>
# </tr>
# <tr>
# <td>
# <b>您的问题与建议</b><span id="errMsg"></span>
# </td>
# </tr>
# <tr>
# <td><textarea class="textarea" id="surveryContent" name="content" type="textarea"></textarea></td>
# </tr>
# <tr>
# <td><b>您的联系方式</b></td>
# </tr>
# <tr>
# <td><input id="surveryContact" name="contact" type="text"/></td>
# </tr>
# <tr>
# <td>
# <div class="fl">
# <input class="identify" id="surveryVerify" maxlength="4" name="code" onkeyup="if(this.value.length==4){ec.survery.validate();}" type="text"/>  <img alt="验证码" class="vam" id="surveryVerifyImg" onclick="ec.survery.reloadCode()"/>    <span class="vam"><a class="u" href="javascript:;" onclick="ec.survery.reloadCode();">换一张</a></span>
# </div>
# <div class="fr">
# <a class="button-action-yes" href="javascript:;" onclick="ec.survery.submit();"><span>提交</span></a>
# </div>
# </td>
# </tr>
# </tbody>
# </table>
# </div>
# </form>
# </div>
# </div>
# </div>
# <!-- -表单-意见反馈-end -->
# </div>
# </td>
# <td class="box-cr"></td>
# </tr>
# </tbody>
# </table>
# <div class="box-bottom">
# <div class="box-bl"></div>
# <div class="box-bc"></div>
# <div class="box-br"></div>
# </div>
# </div>
# </div>
# <div class="hide" context="" id="globleParameter" imagepath="https://res.vmallres.com/20191126/images" mediapath="https://res.vmallres.com/pimages/" scriptpath="https://res9.vmallres.com/20191126/js" stylepath="https://res8.vmallres.com/20191126/css"></div>
# <form action="/order/confirmcart" id="miniCartForm" method="post"></form>
# <!-- 2017-02-15-底部-start -->
# <div class="footer-container">
# <div class="footer">
# <div class="footer-warrant-area clearfix"><p class="footer-warrant-logo fl"><a href="https://www.vmall.com"><img src="https://res.vmallres.com/pimages//sale/2019-01/wLelYbpMVWbj9Xpaa5Fk.png" title="华为商城"/></a></p><div class="fl"><ul class="footer-warrant-link"><li><a href="https://www.huawei.com/cn/">华为集团</a></li><li><a href="https://consumer.huawei.com/cn/">华为CBG官网</a></li><li><a href="http://www.honor.cn/">荣耀官网</a></li><li><a href="https://club.huawei.com/">花粉俱乐部</a></li><li><a href="http://appstore.huawei.com/">华为应用市场</a></li><li><a href="https://emui.huawei.com/cn/">EMUI</a></li><li><a href="https://cloud.huawei.com">华为终端云空间</a></li><li><a href="https://developer.huawei.com/cn/">开发者联盟</a></li><li><a href="https://m.vmall.com/">华为商城手机版</a></li><li><a href="https://www.vmall.com/shopdc/sitemap.html">网站地图</a></li></ul><a href="https://www.vmall.com/help/faq-2635.html" rel="nofollow" target="_blank" title="隐私声明">隐私声明</a> <a href="https://www.vmall.com/help/faq-778.html" rel="nofollow" target="_blank" title="服务协议">服务协议</a> <a href="https://www.vmall.com/help/faq-11810.html" rel="nofollow" target="_blank" title="COOKIES">COOKIES</a> Copyright © 2012-<span id="j-copyrightyear">2020</span> 华为终端有限公司 版权所有 <a href="http://beian.miit.gov.cn/" target="_blank">粤ICP备19015064号</a><em>|</em><a href="http://www.beian.gov.cn/portal/registerSystemInfo?recordcode=44190002003939" target="_blank">粤公网安备 44190002003939号</a><br/>增值电信业务经营许可证：粤B2-20190762<em>|</em>备案主体编号：44201919072182</div><p class="fr footer-warrant-img"><a class="fl" href="https://res.vmallres.com/pimages///sale/2019-04/Vhy8y3yxVJXg0FE74dh0.png" target="_blank"><img alt="电子营业执照" src="https://res.vmallres.com/pimages//template/content/2016/20160226162415360.png" title="电子营业执照"/></a></p></div><script>$("#j-copyrightyear").text((new Date()).getFullYear());</script>
# </div>
# </div>
# <!-- 2017-02-15-底部-end -->
# <!--<script src="https://res9.vmallres.com/20191126/js/echannel/slider.min.js?20170426"></script>-->
# <!--<script src="https://res9.vmallres.com/20191126/js/echannel/swiper.min.js?20170426"></script>-->
# <script>
#     new Slider({//友情链接
#         objid: '#serverlink',
#         listname: '.service-list',
#         listitem: 'ol',
#         shownum: 1
#     }).init();
#
# ec.load("ec.box" , {loadType : "lazy"});
# /**
# *功能：给鼠标移动到s-dropdown上面的时候，记得给他多添加一个hover类样式
# *目的是兼容ie6
# *@author 李峰
# */
# $(function(){
#     $(".s-dropdown").hover(function(){
#         var jTpl = $(this).attr('data-tpl');
#         if (jTpl && $(this).find('.b').length < 1) {
#             $(this).append($('#'+jTpl).val());
#             $(this).removeAttr('data-tpl');
#         }
#         $(this).addClass("hover");
#     },function(){
#         $(this).removeClass("hover");
#     });
#     var maxcolor=$('.top-banner-max').find('p').children('a').css("background-color");
#     var mincolor=$('.top-banner-min').find('p').children('a').css("background-color");
#
#     $('.top-banner-max').css({"background-color":maxcolor,overflow:"hidden"});
#     $('.top-banner-min').css({"background-color":mincolor,overflow:"hidden"});
# });
#
# //显示全球导航选择层
# function showSelectRegion()
# {
#     var box = new ec.box($("#selectRegion-tips").val(),
#     {
#             boxid : "region-select-box",
#             boxclass : "ol_box_4",
#             title : "Please select your country or region",
#             width : 700,
#             showButton : false,
#             autoPosition:false,
#             onopen: function(box){
#             },
#             onok : function(box){
#             },
#             oncancel : function(box){
#                 box.close();
#                 $(".ol_box_mask").remove();
#             },
#             onclose : function(box){
#                 $(".ol_box_mask").remove();
#             }
#         });
#
#         box.open();
#
#         $(".box-title").css("font-size","24px");
#         $("#region-select-box").css("height","auto");
#         $(".ol_box_mask").click(function(){box.close();});
#
#         $(".box-header").unbind("mousemove");
#         $(".box-header").unbind("mousedown");
#
#         var divTop=document.getElementById("region-select-box").offsetTop;
#         $("#region-select-box").mousedown(function (e)
#         {
#             var e=e||window.event;
#             var region = document.getElementById("region-select-box");
#
#             var leftX = e.clientX - region.offsetLeft;
#             var topY = e.clientY - region.offsetTop;
#             $("#region-select-box").mousemove(function (event)
#             {
#               var e=event||window.event;
#               var left=    e.clientX - leftX;
#               var top=e.clientY - topY;
#
#               if(e.clientX - leftX<20-region.offsetWidth){
#               left=20-region.offsetWidth;
#               }
#               if(e.clientY - topY<20-region.offsetHeight){
#               top=20-region.offsetHeight;
#               }
#
#              if(e.clientY - topY+20>=$(window).height()){
#               top=$(window).height() - 20;
#               }
#               if(e.clientX - leftX+20>=$(window).width()){
#               left=$(window).width() - 20;
#               }
#               $("#region-select-box").css({"left": left, "top": top});
#               divTop=top;
#
#             });
#         });
#         $("#region-select-box").mouseup(function () {
#         $("#region-select-box").unbind("mousemove");
#         });
#         $(window).scroll(function () {
#             $("#region-select-box").offset({ top: divTop });
#         });
# }
#
# ec.load("ec.slider", {
#    loadType : "lazy",
#    callback : function() {
#         $("#ec-erweima").slider({
#                  width:     91, //必须
#                  height:     96, //必须
#                  style : 1,                    //1显示分页，2只显示左右箭头,3两者都显示
#                  pause : 120000,           //间隔时间
#                  auto : true
#         });
#    }
# });
#
# ec.ready(function(){
#     try
#     {
#         	ec.minicart.readyContent();
#         	ec.minicart.microCartTpl = new ec.template($('#micro-cart-tpl').val());
#             var $miniCart = $('#header-toolbar-minicart-content');
#             $('#header-toolbar-minicart').hover(function ()
#             {
#                 if(ec.checkBrowerIE())
#                 {
#                     var act = (document.activeElement || {}).id;
#                     if(act=='search-kw')
#                     {
#                         $("#search-kw").blur();
#                     }
#                 }
#
#                 $(this).unbind("mouseenter");
#                 ec.minicart.content();
#             }, function ()
#             {
#                 $(this).bind("mouseenter",function()
#                 {
#                     if(ec.checkBrowerIE())
#                     {
#                         var act = (document.activeElement || {}).id;
#                         if(act=='search-kw')
#                         {
#                             $("#search-kw").blur();
#                         }
#                     }
#
#                     $(this).unbind("mouseenter");
#                     ec.minicart.content();
#                 });
#             });
#         var vmallcontact="400-088-6888";
#         $.ajax({
#             url: openApiDomain + "/mcp/querySystemConfig?portal=1&lang=zh-CN&country=CN&systemConfigKeys=[\"VMALL_HOT_LINE\"] ",
#             type:"get",
#             dataType: "json",
#             timeout: 10000,
#             async: false,
#             success: function (json) {
#                 if(json.success&&json.systemConfigInfos&&json.systemConfigInfos.VMALL_HOT_LINE&&json.systemConfigInfos.VMALL_HOT_LINE.systemConfigValue){
#                     vmallcontact=json.systemConfigInfos.VMALL_HOT_LINE.systemConfigValue.transHtmlAttribute().replace(/[^\d-/\s]*/g,'');
#                     if(vmallcontact.replace(/\s*/g, "")==""){
#                         vmallcontact="400-088-6888";
#                     }
#                 }
#             }
#         });
#         $("#vmallcontact").text(vmallcontact);
#
#
#         $('#up_loginName-hover').hover(function ()
#         {
#             if(ec.checkBrowerIE())
#             {
#                 var act = (document.activeElement || {}).id;
#                 if(act=='search-kw')
#                 {
#                     $("#search-kw").blur();
#                 }
#             }
#
#             $(this).unbind("mouseenter");
#         }, function ()
#         {
#             $(this).bind("mouseenter",function()
#             {
#                 if(ec.checkBrowerIE())
#                 {
#                     var act = (document.activeElement || {}).id;
#                     if(act=='search-kw')
#                     {
#                         $("#search-kw").blur();
#                     }
#                 }
#
#                 $(this).unbind("mouseenter");
#             });
#         });
#
# }
# catch (err)
# {
#     // console.log(err);
# }
#
# });
# // 更新购物车数字
# $(function(){
#     $('.j-hungBar .hungBar-cart').hover(function(){
#         ec.minicart.updateMiniCartNum();
#     });
# });
#
# (function(){
#     var bp = document.createElement('script');
#     var curProtocol = window.location.protocol.split(':')[0];
#     if (curProtocol === 'https'){
#    bp.src = 'https://zz.bdstatic.com/linksubmit/push.js';
#   }
#   else{
#   bp.src = 'http://push.zhanzhang.baidu.com/push.js';
#   }
#     var s = document.getElementsByTagName("script")[0];
#     s.parentNode.insertBefore(bp, s);
# })();
#
# function pushMyOrderMsg() {
#   ec.account.afterLogin(function() {
#     ec.redirectTo("https://www.vmall.com/member/order?t=1581318515799timestamp");
#   });
#   ec.dapClick(300000301, {
#     "click": "1"
#   });
# }
#
# function pushMyCartMsg() {
#   ec.dapClick(300000401, {
#     "click": "1"
#   });
# }
#
#
# function pushCartProMsg(skuId, url, location) {
#   ec.dapClick(300000402, {
#     "SKUID": skuId,
#     "URL": url,
#     "location": location,
#     "click": "1"
#   });
# }
#
# function pushFootAdvertMsg(name, url) {
#   ec.dapClick(300000501, {
#     "name": name,
#     "URL": url,
#     "click": "1"
#   });
# }
#
# $(".fl").find("dd").find("a").bind("click",function(){
# 	var HREF = "";
# 	HREF = this.href;
# 	var name = this.innerHTML;
# 	if(HREF==null || HREF == "")
# 	{
# 		return;
# 	}
# 	if(this.id=="tools-nav-service-robotim-button")
# 	{
# 		name = "在线客服";
# 	}
# 	if(this.className=="service-btn btn-report")
# 	{
# 		name = "不良信息举报";
# 	}
# 	pushFootAdvertMsg(name,HREF);
# });
#
#
# $('.footer-warrant-area.clearfix a').click(function() {
#   var dapData = {
#     "URL": $(this).attr("href"),
#     "click": "1"
#   };
#   if ($(this).find('img').length > 0) {
#     dapData.ADID = $(this).find("img").attr("src");
#   } else {
#     dapData.name = $(this).text();
#   }
#   ec.dapClick(300000502, dapData);
# });
#
# function pushRightHelpMsg(index) {
#   var buttonName = ['', '购物车', '在线客服', '意见反馈'][index];
#   ec.dapClick(300000601, {
#     "buttonName": buttonName,
#     "click": "1",
#     'index': index
#   });
# }
#
# jump = function(url,obj)
# {
# 	if(typeof(obj.html()) != "undefined" && obj.html() != null && obj.html() != "")
# 	{
# 		pushFootAdvertMsg($(this).html(),url);
# 	}
# 	var win = ec.openWindow(url);
# 	win.opener = null ;
# }
#
# function pushProHotMsg(skuCode) {
#   ec.dapClick(300020701, {
#     "productId": ec.product.id,
#     "SKUCode": (ec.product.getSkuInfo(ec.product.getSku()) || {}).code,
#     "linkSKUCode": skuCode,
#     "click": "1"
#   });
# }
#
# $('#serverlink a').each(function() {
# 	var $a = $(this);
# 	var url = $a.attr('onclick') || '';
# 	url = url.toString();
# 	var m = url.match(/jump_link\('([^']+)'\)/);
# 	if (m && m[1]) {
# 		url = m[1];
# 		$a.attr('target', '_blank').attr('href', url);
# 	}
# });
# jump_link = function(url) {
# 	return;
# }
# </script>
# </body></html>

# %%
A = soup.find_all(id = "pro-price-hide")
A
# Out:
# [<input id="pro-price-hide" type="hidden" value="3199.00"/>]

# %%
B = A[0]['value']
B[:-3]
# Out:
# '3199'

# %% [markdown]
# # Vivo

# %%
# 官網
# https://shop.vivo.com.cn/wap/product/10001939
# call Api
import requests
import json
url = 'https://shop.vivo.com.cn/wap/fbApi/v1/product/getDetail.json?spuId=10001939'
r = requests.get(url)
response = json.loads(r.text)

response['data']['102963']['salePrice']
# Out:
# 4998.0

# %% [markdown]
# # OPPO

# %%
from bs4 import BeautifulSoup as Bt4
import requests
import json
# oppo find X2 Pro
website = f"https://www.opposhop.cn/products/1122.html"

source = requests.get(website).text
soup = Bt4(source, "lxml")

A = soup.select('p.product-price')
B = A[0].getText()

B[3:-4]
# Out:
# '6999'

# %%
# oppo find X2
website = f"https://www.opposhop.cn/products/1119.html"

source = requests.get(website).text
soup = Bt4(source, "lxml")

A = soup.select('p.product-price')
B = A[0].getText()

B[3:-4]
# Out:
# '5499'

# %% [markdown]
# # 小米

# %%
import requests
import json
# 小米10 Pro
headers = {
    "Referer": "https://item.mi.com/product/10000213.html?selected=10000213&pClass=p"
}

url = f'https://api.order.mi.com/product/get?jsonpcallback'+\
'=proget2callback&product_id=10000213'
r = requests.get(url,headers=headers)
tt = r.text.lstrip(' proget2callback(')
tt = tt.rstrip(');\r\n')

response = json.loads(tt)
price = response['data']['list'][0]['list'][0]['goods']['market_price']
price
# Out:
# '4999'

# %%
# 小米10
headers = {
    "Referer": "https://item.mi.com/product/10000214.html?selected=10000214&pClass=p"
}

url = f'https://api.order.mi.com/product/get?jsonpcallback'+\
'=proget2callback&product_id=10000214'
r = requests.get(url,headers=headers)
print(r)
tt = r.text.lstrip(' proget2callback(')
tt = tt.rstrip(');\r\n')

response = json.loads(tt)
price = response['data']['list'][0]['list'][0]['goods']['market_price']
price
# Out:
# <Response [200]>
# '3999'

# %%
for product, num in huawei_list.items():
    print(product,num)
# Out:
# P40 10086013232739
# P40-Pro 10086715691479

# %%
from bs4 import BeautifulSoup as Bt4
import requests
import json
import datetime
def update_res(res,product,price):
    d = {}
    d["Product"] = product
    d["Timestamp"] = datetime.datetime.today().strftime("%Y-%m-%d")
    d["Dealprice"] = price
    
    res.append(d)
    return res

# 華為
def get_data_huawei(res,huawei_list):

    # num 是網址列要放的東西
    for product, num in huawei_list.items():
        
        website = f"https://www.vmall.com/product/{num}.html"
        source = requests.get(website).text
        soup = Bt4(source, "lxml")

        A = soup.find_all(id = "pro-price-hide")
        B = A[0]['value']
        
        price = B[:-3]
        update_res(res,product,price)
        
    return(res)
def get_data_oppo(res, product_list):

    for product, num in product_list.items():
        # oppo find X2 Pro
        website = f"https://www.opposhop.cn/products/{num}.html"
        source = requests.get(website).text
        soup = Bt4(source, "lxml")

        A = soup.select('p.product-price')
        B = A[0].getText()

        price = B[3:-4]

        update_res(res,product,price)
    return(price)
def get_data_vivo(res, product_list):
# VIVO
# 官網
# https://shop.vivo.com.cn/wap/product/10001939
    for product, num in product_list.items():
        url = f'https://shop.vivo.com.cn/wap/fbApi/v1/product/getDetail.json?spuId={num}'
        r = requests.get(url)
        response = json.loads(r.text)

        price = response['data']['102963']['salePrice']
        update_res(res,product,price)
        
    return(res)
def get_data_xiomi(res, product_list):

    # 小米10
    for product, num in product_list.items():
        headers = {
            "Referer": f"https://item.mi.com/product/{num}.html?selected={num}&pClass=p"
        }

        url = f'https://api.order.mi.com/product/get?jsonpcallback'+\
        f'=proget2callback&product_id={num}'
        r = requests.get(url,headers=headers)

        tt = r.text.lstrip(' proget2callback(')
        tt = tt.rstrip(');\r\n')

        response = json.loads(tt)
        price = response['data']['list'][0]['list'][0]['goods']['market_price']
        update_res(res,product,price)
    return(price)

huawei_list = {"P40":'10086013232739',"P40-Pro":'10086715691479'}
vivo_list = {"NEX-3S":'10001939'}
oppo_list = {"X2":'1119',"X2-Pro":'1122'}
xiomi_list = {"X10":'10000214',"X10-Pro":'10000213'}

res = []

get_data_huawei(res,huawei_list)
get_data_vivo(res, vivo_list)
get_data_oppo(res, oppo_list)
get_data_xiomi(res,xiomi_list)
res
# Out:
# [{'Product': 'P40', 'Timestamp': '2020-04-09', 'Dealprice': '4488'},
#  {'Product': 'P40-Pro', 'Timestamp': '2020-04-09', 'Dealprice': '6488'},
#  {'Product': 'NEX-3S', 'Timestamp': '2020-04-09', 'Dealprice': 4998.0},
#  {'Product': 'X2', 'Timestamp': '2020-04-09', 'Dealprice': '99'},
#  {'Product': 'X2-Pro', 'Timestamp': '2020-04-09', 'Dealprice': '6999'},
#  {'Product': 'X10', 'Timestamp': '2020-04-09', 'Dealprice': '3999'},
#  {'Product': 'X10-Pro', 'Timestamp': '2020-04-09', 'Dealprice': '4999'}]
